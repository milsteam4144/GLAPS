# %%
import os
import sqlalchemy
from sqlalchemy import create_engine
import pandas as pd

"""
Gets data from DB
"""
path = os.path.abspath("MinorLeague.db")
engine = create_engine("sqlite:///"+path, echo = False)#Set to false to git rid of log
#Link a session to the engine and initialize it
conn = engine.connect()

df = pd.read_sql_table('Detailed', conn)
df = df[:800]
df = df.drop(['CountyCode'], axis = 1)
df = df.drop(['Year'], axis = 1)
df['StateCode'] = pd.to_numeric(df['StateCode'],errors='coerce').fillna(0)

features = ["StateCode", "population", "medianRealEstateTax", "medianHousholdCosts",
            "totalHouses", "Target"]

#randomly takes 50% of the DB dataset and places it in train
train_data = df.sample(frac = 0.5, random_state=800)

#places remaining items in test db
test_data = df.drop(train_data.index)

# Display the Dive visualization for the training data.
from IPython.core.display import display, HTML

jsonstr = train_data.to_json(orient='records')
HTML_TEMPLATE = """<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html">
        <facets-dive id="elem" height="600"></facets-dive>
        <script>
          var data = {jsonstr};
          document.querySelector("#elem").data = data;
        </script>"""
html = HTML_TEMPLATE.format(jsonstr=jsonstr)
display(HTML(html))
# Out:
# <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html">
#         <facets-dive id="elem" height="600"></facets-dive>
#         <script>
#           var data = [{"StateCode":45,"population":389116,"medianRealEstateTax":1133,"medianHouseholdCosts":951,"totalHouses":86225,"medianHomeVal":149400},{"StateCode":55,"population":83943,"medianRealEstateTax":3323,"medianHouseholdCosts":1018,"totalHouses":23828,"medianHomeVal":173200},{"StateCode":6,"population":449253,"medianRealEstateTax":1361,"medianHouseholdCosts":887,"totalHouses":76347,"medianHomeVal":152500},{"StateCode":40,"population":77988,"medianRealEstateTax":1035,"medianHouseholdCosts":732,"totalHouses":16186,"medianHomeVal":127800},{"StateCode":48,"population":64726,"medianRealEstateTax":1621,"medianHouseholdCosts":758,"totalHouses":14007,"medianHomeVal":96200},{"StateCode":12,"population":195823,"medianRealEstateTax":2564,"medianHouseholdCosts":1192,"totalHouses":57923,"medianHomeVal":235900},{"StateCode":47,"population":268921,"medianRealEstateTax":1216,"medianHouseholdCosts":981,"totalHouses":66202,"medianHomeVal":158400},{"StateCode":36,"population":199031,"medianRealEstateTax":2683,"medianHouseholdCosts":738,"totalHouses":52647,"medianHomeVal":109400},{"StateCode":15,"population":963607,"medianRealEstateTax":1567,"medianHouseholdCosts":1551,"totalHouses":168912,"medianHomeVal":544300},{"StateCode":39,"population":161624,"medianRealEstateTax":2049,"medianHouseholdCosts":874,"totalHouses":41087,"medianHomeVal":155200},{"StateCode":53,"population":203663,"medianRealEstateTax":2320,"medianHouseholdCosts":1073,"totalHouses":51859,"medianHomeVal":270900},{"StateCode":13,"population":65451,"medianRealEstateTax":1634,"medianHouseholdCosts":978,"totalHouses":13123,"medianHomeVal":139900},{"StateCode":37,"population":96116,"medianRealEstateTax":1026,"medianHouseholdCosts":805,"totalHouses":23658,"medianHomeVal":123900},{"StateCode":39,"population":173262,"medianRealEstateTax":2551,"medianHouseholdCosts":1076,"totalHouses":52148,"medianHomeVal":173800},{"StateCode":13,"population":143925,"medianRealEstateTax":1294,"medianHouseholdCosts":896,"totalHouses":35809,"medianHomeVal":125500},{"StateCode":54,"population":192315,"medianRealEstateTax":663,"medianHouseholdCosts":644,"totalHouses":55988,"medianHomeVal":98500},{"StateCode":55,"population":88661,"medianRealEstateTax":3051,"medianHouseholdCosts":933,"totalHouses":24033,"medianHomeVal":158100},{"StateCode":42,"population":412778,"medianRealEstateTax":3179,"medianHouseholdCosts":974,"totalHouses":112173,"medianHomeVal":168300},{"StateCode":48,"population":82487,"medianRealEstateTax":1203,"medianHouseholdCosts":664,"totalHouses":23838,"medianHomeVal":87300},{"StateCode":21,"population":121737,"medianRealEstateTax":1570,"medianHouseholdCosts":1082,"totalHouses":33642,"medianHomeVal":171300},{"StateCode":17,"population":170556,"medianRealEstateTax":3517,"medianHouseholdCosts":912,"totalHouses":41959,"medianHomeVal":157500},{"StateCode":55,"population":251412,"medianRealEstateTax":2980,"medianHouseholdCosts":890,"totalHouses":67807,"medianHomeVal":155900},{"StateCode":51,"population":442707,"medianRealEstateTax":2339,"medianHouseholdCosts":1408,"totalHouses":105566,"medianHomeVal":264300},{"StateCode":32,"population":425710,"medianRealEstateTax":1809,"medianHouseholdCosts":1038,"totalHouses":92389,"medianHomeVal":177400},{"StateCode":22,"population":432640,"medianRealEstateTax":784,"medianHouseholdCosts":882,"totalHouses":104258,"medianHomeVal":172000},{"StateCode":36,"population":1498816,"medianRealEstateTax":7942,"medianHouseholdCosts":1954,"totalHouses":392826,"medianHomeVal":383400},{"StateCode":12,"population":169856,"medianRealEstateTax":1014,"medianHouseholdCosts":933,"totalHouses":43511,"medianHomeVal":156000},{"StateCode":13,"population":156433,"medianRealEstateTax":1457,"medianHouseholdCosts":800,"totalHouses":30720,"medianHomeVal":131400},{"StateCode":17,"population":113698,"medianRealEstateTax":2897,"medianHouseholdCosts":891,"totalHouses":29074,"medianHomeVal":138200},{"StateCode":28,"population":75842,"medianRealEstateTax":1021,"medianHouseholdCosts":710," ...

# %%
# Clone the facets github repo to get access to the python feature stats generation code
# %git clone https://github.com/pair-code/facets.git
# Out:
# UsageError: Line magic function `%git` not found.

# %%
# Add the path to the feature stats generation code.
import sys
sys.path.insert(0, '/content/facets/facets_overview/python/')

# Create the feature stats for the datasets and stringify it.
import base64
from generic_feature_statistics_generator import GenericFeatureStatisticsGenerator

gfsg = GenericFeatureStatisticsGenerator()
proto = gfsg.ProtoFromDataFrames([{'name': 'train', 'table': train_data},
                                  {'name': 'test', 'table': test_data}])
protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-4237fbd938a7> in <module>()
#       5 # Create the feature stats for the datasets and stringify it.
#       6 import base64
# ----> 7 from generic_feature_statistics_generator import GenericFeatureStatisticsGenerator
#       8
#       9 gfsg = GenericFeatureStatisticsGenerator()
#
# ModuleNotFoundError: No module named 'generic_feature_statistics_generator'

# %%
# Display the facets overview visualization for this data
from IPython.core.display import display, HTML

HTML_TEMPLATE = """<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html" >
        <facets-overview id="elem"></facets-overview>
        <script>
          document.querySelector("#elem").protoInput = "{protostr}";
        </script>"""
html = HTML_TEMPLATE.format(protostr=protostr)
display(HTML(html))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f5e574697574> in <module>()
#       7           document.querySelector("#elem").protoInput = "{protostr}";
#       8         </script>"""
# ----> 9 html = HTML_TEMPLATE.format(protostr=protostr)
#      10 display(HTML(html))
#
# NameError: name 'protostr' is not defined
